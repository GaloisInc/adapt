# %%
# %matplotlib inline

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
pg = nx.gn_graph(100)
nx.draw(pg)

# %%
nx.draw_random(pg)

# %%
nx.draw_circular(pg)

# %%
nx.draw_spectral(pg)

# %%
print pg
# Out:
# gn_graph(100)

# %%
pg[1][0]['aaa'] =1

# %%
print pg[1]
# Out:
# {0: {'aaa': 1}}

# %%
er=nx.erdos_renyi_graph(30,0.15)

# %%
dg = nx.DiGraph(er)

# %%
nx.draw(dg)
